# %% [markdown]
# # Finite-Element-Program for 1D problems

# %% [markdown]
# ## Load libaries

# %%
import numpy as np
import matplotlib.pyplot as plt
from fjFEM1D_lib import post_proc

# %% [markdown]
# ## Discretization
#
# Example 1.5
#
# ![image.png](attachment:image.png)

# %%
# number of elements
n = 

# nodes
N = 

# elements
E = 

# elment type
eType = 

# material properties
EA = 

# external force
F = 

# constand line load
p = 

# boundary conditons
BC =

# %% [markdown]
# ## Finite-Element-Method
#
# Determine nodal displacements

# %%
# *** START FINITE ELEMENT ANALYSIS ***

# --- DIRECT STIFFNESS METHOD ---

# --- APPLY BOUNDARY CONDITIONS ---

# --- SOLVE SYSTEM OF EQUATIONS ---
u =

# %% [markdown]
# ## Post-Processing
#
# Plot axial displacement and force

# %%
post_proc(N, E, u, eType, F, EA)
plt.show()
